# %%
import requests
from pyquery import PyQuery as pq
def parse(url):
    response = requests.get(url)
    response.encoding = 'utf-8'
    html = response.text
    doc = pq(html)
    items = doc('.article #Zoom .zw-con')
    for item in items.items():
        title = doc('.article .Article_bt')
        title = items.find('h1').text()
        content = item.find('p').text()
        print('公文标题：',title)
        print('公文正文：',content)
def main():
    urls = ['http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171206_1084576.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171206_1084575.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171206_1084574.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201711/t20171129_1083571.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201711/t20171127_1083261.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201711/t20171127_1083259.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201711/t20171127_1083258.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171220_1086442.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171220_1086441.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171220_1086440.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201711/t20171127_1083255.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201710/t20171031_1078834.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201710/t20171025_1078077.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201710/t20171019_1077303.html', 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201710/t20171019_1077299.html']
    i = 0
    for url in urls:
        i += 1 
        print('-'*65,i,'-'*65)
        parse(url)
        
if __name__ == '__main__':
    main()
# Out:
# ----------------------------------------------------------------- 1 -----------------------------------------------------------------
# 公文标题：
# ...

# %%
import requests
from pyquery import PyQuery as pq
url = 'http://www.gzgov.gov.cn/xxgk/jbxxgk/fgwj/gjflfgjgz/201712/t20171206_1084576.html'
response = requests.get(url)
response.encoding = 'utf-8'
html = response.text
doc = pq(html)
title = doc('.article .Article_bt')
title = items.find('h1').text()
# items = doc('#Zoom .zw-con')
# for item in items.items():
#     print(item)
#     title = item.find('hi').text()
#     context = item.find('p').text()
#     print(context)
print(title)
# Out:
# 国务院办公厅关于推动国防科技工业军民融合深度发展的意见
